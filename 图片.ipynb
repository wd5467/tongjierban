# %%
import requests
response = requests.get('https://ss3.bdstatic.com/70cFv8Sh_Q1YnxGkpoWK1HF6hhy/it/u=742727944,1003082663&fm=27&gp=0.jpg')
print(response.content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x01w\x01\xf4\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94\x95\x96\x97\x98\x99\x9a\xa2\xa3\xa4\xa5\xa6\xa7\xa8\xa9\xaa\xb2\xb3\xb4\xb5\xb6\xb7\xb8\xb9\xba\xc2\xc3\xc4\xc5\xc6\xc7\xc8\xc9\xca\xd2\xd3\x
# ...

# %%
import requests
response = requests.get('https://ss3.bdstatic.com/70cFv8Sh_Q1YnxGkpoWK1HF6hhy/it/u=742727944,1003082663&fm=27&gp=0.jpg')
print(response.content)
with open('C:\\Users\\MacBook\\Desktop\\test.jpg','wb')as f:
    f.write(response.content)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x01w\x01\xf4\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94\x95\x96\x97\x98\x99\x9a\xa2\xa3\xa4\xa5\xa6\xa7\xa8\xa9\xaa\xb2\xb3\xb4\xb5\xb6\xb7\xb8\xb9\xba\xc2\xc3\xc4\xc5\xc6\xc7\xc8\xc9\xca\xd2\xd3\x
# ...

# %%
import requests
response = requests.get('https://www.baidu.com/s?ie=utf-8&f=8&rsv_bp=0&rsv_idx=1&tn=78000241_13_hao_pg&wd=%E5%96%B5%E6%98%9F%E4%BA%BA%E5%9B%BE%E7%89%87&rsv_pq=87486f4b0006072e&rsv_t=cf81wVeyt3TqPHzxEE7FABCnyIgQ86yc7BwyaLF4dWkvNupEYiClMjqmjExcLpmdzzCMFIv5c53v&rqlang=cn&rsv_enter=1&rsv_sug3=21&rsv_sug1=16&rsv_sug7=100')
print(response.text)
with open('C:\\Users\\MacBook\\Desktop\\html','w',encoding='utf-8')as f:
    f.write(response.text)
# Out:
# <html>
# <head>
# 	<script>
# 		location.replace(location.href.replace("https://","http://"));
# 	</script>
# </head>
# <body>
# 	<noscript><meta http-equiv="refresh" content="0;url=http://www.baidu.com/"></noscript>
# </body>
# </html>

# %%
import requests
login = {'account':'124567894','password':'123456'}
response = requests.post('',data=login)
print(response.text)

# %%
import requests
response = requests.get('http://www.zhihu.com/explore')
print(response.text)
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %%
import requests
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.79 Safari/537.36'}
response = requests.get('http://www.zhihu.com/explore',headers = header)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" dropEffect="none" class="no-js no-auth ">
# <head>
# <meta charset="utf-8" />
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <meta name="renderer" content="webkit" />
# <meta http-equiv="X-ZA-Response-Id" content="f3ef131024b50270403a7a19d18d84fc">
#
# ...

# %%
import requests
requests.get('http://httpbin.org/cookies/set/number/123456')
response=requests.get('http://httpbin.org/cookies')
print(response.text)
# Out:
# {"cookies":{}}

# %%
import requests
s=requests.Session()   #通过声明说明session他俩一样
s.get('http://httpbin.org/cookies/set/number/123456')
response=s.get('http://httpbin.org/cookies')
print(response.text)
# Out:
# {"cookies":{"number":"123456"}}

# %%
import requests
try:
    response = requests.get('http://www.')
    print(response.status_code)
except Exception as e:
    print(e)
# Out:
# HTTPConnectionPool(host='www.', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000258314C3550>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))

# %%
url=['http://www.17k.com/mianfei/','http://www.17k.com/book/2801193.html']
file = 'C:\\Users\\MacBook\\Desktop\\a'
header={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.79 Safari/537.36'}
with open('C:\\Users\\MacBook\\Desktop\\a\\html','a',encoding='utf-8')as f:
    for i in range(2):
        b=requests.get(url[i],headers = header)
        f.write(b.text)
    print(i)
# Out:
# 1

# %%
# Out:
#   File "<ipython-input-21-894b1a26d29f>", line 2
#     import requests
#          ^
# IndentationError: expected an indented block
